# %%
import pandas as pd

# %%
from pandas_profiling import ProfileReport

# %%
data = pd.read_csv('taxi.csv')

# %%
data
# Out:
#        trip_distance  rate_code store_and_fwd_flag  payment_type  fare_amount  \
# 0               9.01          1                  N             1         26.0
# 1               0.20          1                  N             1          3.0
# 2               9.65          1                  N             1         41.5
# 3               9.50          1                  N             1         30.0
# 4               5.80          1                  N             1         21.5
# ...              ...        ...                ...           ...          ...
# 34995          22.43          1                  N             1         59.5
# 34996           9.16          1                  N             1         30.0
# 34997           6.78          1                  N             1         23.0
# 34998           0.26          1                  N             2          3.0
# 34999          18.40          1                  N             1         53.0
#
# ...

# %%
##### generate a report 
profile = ProfileReport(data)

# %%
## save this file as html report 
profile.to_file(output_file='Taxi.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
